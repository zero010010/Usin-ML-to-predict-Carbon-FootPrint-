# %% [markdown]
# <span style="color:blue">**Using Machine Learning to Predict Carbon Footprint:<br> BASIC EDA**</span><br>
#
#
#
#
#
# <img src="/Users/miguelopez/Desktop/4-Proyecto ML/img/carbon.png" width="500">

# %%
# Libraries
import pandas as pd
import os # operating system    
import matplotlib.pyplot as plt
import numpy as np  
import seaborn as sns

# %%
print(os.getcwd())
# Out:
# /Users/miguelopez/Desktop/4-Proyecto ML/src/notebooks

# %% [markdown]
# <span style="color:green">**EDA:**</span>
#  <br>

# %%
df=pd.read_csv('/Users/miguelopez/Desktop/4-Proyecto ML/src/data_raw/Carbon Emission.csv')

# %%
df.head()
# Out:
#     Body Type     Sex         Diet How Often Shower Heating Energy Source  \
# 0  overweight  female  pescatarian            daily                  coal
# 1       obese  female   vegetarian  less frequently           natural gas
# 2  overweight    male     omnivore  more frequently                  wood
# 3  overweight    male     omnivore      twice a day                  wood
# 4       obese  female   vegetarian            daily                  coal
#
#       Transport Vehicle Type Social Activity  Monthly Grocery Bill  \
# 0        public          NaN           often                   230
# 1  walk/bicycle          NaN           often                   114
# 2       private       petrol           never                   138
# 3  walk/bicycle          NaN       sometimes                   157
# 4       private       diesel           often                   266
#
#   Frequency of Traveling by Air  Vehicle Monthly Distance Km Waste Bag Size  \
# 0                    frequently                          210          large
# 1                        rarely                            9    extra large
# 2                         never                         2472          small
# 3                        rarely                           74         medium
# 4               very frequently                         8457          large
#
#    Waste Bag Weekly Count  How Long TV PC Daily Hour  \
# 0                       4                          7
# 1                       3                          9
# 2                       1                         14
# 3                       3                         20
# 4                       1                          3
#
#    How Many New Clothes Monthly  How Long Internet Daily Hour  \
# 0                            26                             1
# 1                            38                             5
# 2                            47                             6
# 3                             5                             7
# 4                             5                             6
#
#   Energy efficiency                               Recycling  \
# 0                No                               ['Metal']
# 1                No                               ['Metal']
# 2         Sometimes                               ['Metal']
# 3         Sometimes  ['Paper', 'Plastic', 'Glass', 'Metal']
# 4               Yes                               ['Paper']
#
#                          Cooking_With  CarbonEmission
# 0                   ['Stove', 'Oven']            2238
# 1              ['Stove', 'Microwave']            1892
# 2               ['Oven', 'Microwave']            2595
# 3  ['Microwave', 'Grill', 'Airfryer']            1074
# 4                            ['Oven']            4743

# %%
df.tail()
# Out:
#         Body Type     Sex         Diet How Often Shower Heating Energy Source  \
# 9995        obese    male     omnivore      twice a day                  coal
# 9996       normal  female        vegan      twice a day                  coal
# 9997   overweight  female   vegetarian            daily           electricity
# 9998  underweight    male        vegan  more frequently                  coal
# 9999        obese    male  pescatarian      twice a day                  wood
#
#          Transport Vehicle Type Social Activity  Monthly Grocery Bill  \
# 9995       private       hybrid       sometimes                   230
# 9996       private          lpg           never                   234
# 9997  walk/bicycle          NaN       sometimes                   298
# 9998       private       petrol           often                   179
# 9999       private     electric       sometimes                   115
#
#      Frequency of Traveling by Air  Vehicle Monthly Distance Km  \
# 9995                         never                          268
# 9996                    frequently                         5316
# 9997               very frequently                           96
# 9998                        rarely                         8688
# 9999                         never                         9952
#
#      Waste Bag Size  Waste Bag Weekly Count  How Long TV PC Daily Hour  \
# 9995         medium                       5                         12
# 9996    extra large                       3                         14
# 9997    extra large                       5                         11
# 9998         medium                       5                         19
# 9999          small                       4                         11
#
#       How Many New Clothes Monthly  How Long Internet Daily Hour  \
# 9995                            27                             9
# 9996                             8                            24
# 9997                             5                            24
# 9998                            14                             5
# 9999                             6                             0
#
#      Energy efficiency                      Recycling  \
# 9995               Yes                             []
# 9996         Sometimes           ['Paper', 'Plastic']
# 9997               Yes  ['Paper', 'Plastic', 'Metal']
# 9998         Sometimes             ['Paper', 'Metal']
# 9999         Sometimes  ['Plastic', 'Glass', 'Metal']
#
#                                      Cooking_With  CarbonEmission
# 9995                                ['Microwave']            2408
# 9996                       ['Stove', 'Microwave']            3084
# 9997           ['Microwave', 'Grill', 'Airfryer']            2377
# 9998  ['Stove', 'Microwave', 'Grill', 'Airfryer']            4574
# 9999                ['Oven', 'Grill', 'Airfryer']             826

# %%
# Null values
df.isnull().sum()
# Out:
# Body Type                           0
# Sex                                 0
# Diet                                0
# How Often Shower                    0
# Heating Energy Source               0
# Transport                           0
# Vehicle Type                     6721
# Social Activity                     0
# Monthly Grocery Bill                0
# Frequency of Traveling by Air       0
# Vehicle Monthly Distance Km         0
# Waste Bag Size                      0
# Waste Bag Weekly Count              0
# How Long TV PC Daily Hour           0
# How Many New Clothes Monthly        0
# How Long Internet Daily Hour        0
# Energy efficiency                   0
# Recycling                           0
# Cooking_With                        0
# CarbonEmission                      0
# dtype: int64

# %%
# Columns names
df.columns
# Out:
# Index(['Body Type', 'Sex', 'Diet', 'How Often Shower', 'Heating Energy Source',
#        'Transport', 'Vehicle Type', 'Social Activity', 'Monthly Grocery Bill',
#        'Frequency of Traveling by Air', 'Vehicle Monthly Distance Km',
#        'Waste Bag Size', 'Waste Bag Weekly Count', 'How Long TV PC Daily Hour',
#        'How Many New Clothes Monthly', 'How Long Internet Daily Hour',
#        'Energy efficiency', 'Recycling', 'Cooking_With', 'CarbonEmission'],
#       dtype='object')

# %%
# Range and Dtypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Body Type                      10000 non-null  object
#  1   Sex                            10000 non-null  object
#  2   Diet                           10000 non-null  object
#  3   How Often Shower               10000 non-null  object
#  4   Heating Energy Source          10000 non-null  object
#  5   Transport                      10000 non-null  object
#  6   Vehicle Type                   3279 non-null   object
#  7   Social Activity                10000 non-null  object
#  8   Monthly Grocery Bill           10000 non-null  int64
#  9   Frequency of Traveling by Air  10000 non-null  object
#  10  Vehicle Monthly Distance Km    10000 non-null  int64
#  11  Waste Bag Size                 10000 non-null  object
#  12  Waste Bag Weekly Count         10000 non-null  int64
#  13  How Long TV PC Daily Hour      10000 non-null  int64
#  14  How Many New Clothes Monthly   10000 non-null  int64
#  15  How Long Internet Daily Hour   10000 non-null  int64
#  16  Energy efficiency              10000 non-null  object
#  17  Recycling                      10000 non-null  object
#  18  Cooking_With                   10000 non-null  object
#  19  CarbonEmission                 10000 non-null  int64
# dtypes: int64(7), object(13)
# memory usage: 1.5+ MB

# %%
# Numerical and categorical features 

numerical = []
categorical = []

for col in df.columns:
    if df[col].dtype == 'int64':
        numerical.append(col)
    elif df[col].dtype == 'object':
        categorical.append(col)

print("Categorical: ",categorical)
print("Numerical: ",numerical)
# Out:
# Categorical:  ['Body Type', 'Sex', 'Diet', 'How Often Shower', 'Heating Energy Source', 'Transport', 'Vehicle Type', 'Social Activity', 'Frequency of Traveling by Air', 'Waste Bag Size', 'Energy efficiency', 'Recycling', 'Cooking_With']
# Numerical:  ['Monthly Grocery Bill', 'Vehicle Monthly Distance Km', 'Waste Bag Weekly Count', 'How Long TV PC Daily Hour', 'How Many New Clothes Monthly', 'How Long Internet Daily Hour', 'CarbonEmission']

# %% [markdown]
# <span style="color:blue">Categoricas Features:</span>
#  <br>
# 'Body Type', 'Sex', 'Diet', 'Heating Energy Source', 'Transport', 'Vehicle Type', 'Cooking_With'
# 'How Often Shower', 'Social Activity', 'Frequency of Traveling by Air'
#
# <span style="color:blue">Numerical Features:</span>
#  <br>
# 'Monthly Grocery Bill', 'Vehicle Monthly Distance Km', 'Waste Bag Weekly Count', 'How Long TV PC Daily Hour', 'How Long Internet Daily Hour'
#
# <span style="color:blue">Target Variable:</span> <br>
# 'CarbonEmission'

# %%
# Categorical features(unique values)

for i in df.columns: 
  if df[i].dtype == 'object': 
    print(f"{i}:")
    print(df[i].unique())
# Out:
# Body Type:
# ['overweight' 'obese' 'underweight' 'normal']
# Sex:
# ['female' 'male']
# Diet:
# ['pescatarian' 'vegetarian' 'omnivore' 'vegan']
# How Often Shower:
# ['daily' 'less frequently' 'more frequently' 'twice a day']
# Heating Energy Source:
# ['coal' 'natural gas' 'wood' 'electricity']
# Transport:
# ['public' 'walk/bicycle' 'private']
# Vehicle Type:
# [nan 'petrol' 'diesel' 'hybrid' 'lpg' 'electric']
# Social Activity:
# ['often' 'never' 'sometimes']
# Frequency of Traveling by Air:
# ['frequently' 'rarely' 'never' 'very frequently']
# Waste Bag Size:
# ['large' 'extra large' 'small' 'medium']
# Energy efficiency:
# ['No' 'Sometimes' 'Yes']
# Recycling:
# ["['Metal']" "['Paper', 'Plastic', 'Glass', 'Metal']" "['Paper']"
#  "['Paper', 'Glass', 'Metal']" '[]' "['Paper', 'Plastic', 'Glass']"
#  "['Glass']" "['Paper', 'Plastic']" "['Plastic']"
#  "['Plastic', 'Glass', 'Metal']" "['Paper', 'Plastic', 'Metal']"
#  "['Paper', 'Glass']" "['Paper', 'Metal']" "['Glass', 'Metal']"
#  "['Plastic', 'Glass']" "['Plastic', 'Metal']"]
# Cooking_With:
# ["['Stove', 'Oven']" "['Stove', 'Microwave']" "['Oven', 'Microwave']"
#  "['Microwave', 'Grill', 'Airfryer']" "['Oven']"
#  "['Stove', 'Oven', 'Microwave']" "['Grill', 'Airfryer']" "['Stove']"
#  "['Stove', 'Oven', 'Microwave', 'Grill', 'Airfryer']"
#  "['Oven', 'Microwave', 'Grill', 'Airfryer']"
#  "['Stove', 'Grill', 'Airfryer']" "['Oven', 'Grill', 'Airfryer']"
#  "['Microwave']" "['Stove', 'Oven', 'Grill', 'Airfryer']"
#  "['Stove', 'Microwave', 'Grill', 'Airfryer']" '[]']

# %%
# Statistics
df.describe().T
# Out:
#                                 count       mean          std    min     25%  \
# Monthly Grocery Bill          10000.0   173.8752    72.234018   50.0   111.0
# Vehicle Monthly Distance Km   10000.0  2031.4859  2769.715597    0.0    69.0
# Waste Bag Weekly Count        10000.0     4.0246     1.990375    1.0     2.0
# How Long TV PC Daily Hour     10000.0    12.1392     7.106369    0.0     6.0
# How Many New Clothes Monthly  10000.0    25.1090    14.698725    0.0    13.0
# How Long Internet Daily Hour  10000.0    11.8891     7.277218    0.0     6.0
# CarbonEmission                10000.0  2269.1473  1017.675247  306.0  1538.0
#
#                                  50%      75%     max
# Monthly Grocery Bill           173.0   237.00   299.0
# Vehicle Monthly Distance Km    823.0  2516.75  9999.0
# Waste Bag Weekly Count           4.0     6.00     7.0
# How Long TV PC Daily Hour       12.0    18.00    24.0
# How Many New Clothes Monthly    25.0    38.00    50.0
# How Long Internet Daily Hour    12.0    18.00    24.0
# CarbonEmission                2080.0  2768.00  8377.0

# %%
df.isna().sum()
# Out:
# Body Type                           0
# Sex                                 0
# Diet                                0
# How Often Shower                    0
# Heating Energy Source               0
# Transport                           0
# Vehicle Type                     6721
# Social Activity                     0
# Monthly Grocery Bill                0
# Frequency of Traveling by Air       0
# Vehicle Monthly Distance Km         0
# Waste Bag Size                      0
# Waste Bag Weekly Count              0
# How Long TV PC Daily Hour           0
# How Many New Clothes Monthly        0
# How Long Internet Daily Hour        0
# Energy efficiency                   0
# Recycling                           0
# Cooking_With                        0
# CarbonEmission                      0
# dtype: int64

# %%
# Correlations  
df.corr(numeric_only=True)
# Out:
#                               Monthly Grocery Bill  \
# Monthly Grocery Bill                      1.000000
# Vehicle Monthly Distance Km               0.015801
# Waste Bag Weekly Count                    0.002343
# How Long TV PC Daily Hour                -0.010318
# How Many New Clothes Monthly              0.006746
# How Long Internet Daily Hour              0.012798
# CarbonEmission                            0.081587
#
#                               Vehicle Monthly Distance Km  \
# Monthly Grocery Bill                             0.015801
# Vehicle Monthly Distance Km                      1.000000
# Waste Bag Weekly Count                          -0.001730
# How Long TV PC Daily Hour                       -0.003943
# How Many New Clothes Monthly                     0.004934
# How Long Internet Daily Hour                    -0.003497
# CarbonEmission                                   0.594171
#
#                               Waste Bag Weekly Count  \
# Monthly Grocery Bill                        0.002343
# Vehicle Monthly Distance Km                -0.001730
# Waste Bag Weekly Count                      1.000000
# How Long TV PC Daily Hour                  -0.011640
# How Many New Clothes Monthly               -0.003254
# How Long Internet Daily Hour               -0.005335
# CarbonEmission                              0.159193
#
#                               How Long TV PC Daily Hour  \
# Monthly Grocery Bill                          -0.010318
# Vehicle Monthly Distance Km                   -0.003943
# Waste Bag Weekly Count                        -0.011640
# How Long TV PC Daily Hour                      1.000000
# How Many New Clothes Monthly                   0.009414
# How Long Internet Daily Hour                   0.006804
# CarbonEmission                                 0.012985
#
#                               How Many New Clothes Monthly  \
# Monthly Grocery Bill                              0.006746
# Vehicle Monthly Distance Km                       0.004934
# Waste Bag Weekly Count                           -0.003254
# How Long TV PC Daily Hour                         0.009414
# How Many New Clothes Monthly                      1.000000
# How Long Internet Daily Hour                      0.006426
# CarbonEmission                                    0.198887
#
#                               How Long Internet Daily Hour  CarbonEmission
# Monthly Grocery Bill                              0.012798        0.081587
# Vehicle Monthly Distance Km                      -0.003497        0.594171
# Waste Bag Weekly Count                           -0.005335        0.159193
# How Long TV PC Daily Hour                         0.006804        0.012985
# How Many New Clothes Monthly                      0.006426        0.198887
# How Long Internet Daily Hour                      1.000000        0.043878
# CarbonEmission                                    0.043878        1.000000

# %%
# Heatmap  
sns.heatmap(df.corr(numeric_only=True), annot=True,cmap='Blues')
# Out:
# <AxesSubplot: >

# %% [markdown]
# * <span style="color:blue">Strong positive correlation:</span><br>
# Vehicle monthly distance
#
# * <span style="color:blue">Moderate positive correlation:</span>
#  <br>
# Grocery bill, clothes purchases, and waste generation
#
# * <span style="color:blue">Weak positive correlation:</span><br>
# TV/PC use and internet use

# %%
# Target Hist

sns.set_style("darkgrid")
plt.figure(figsize=(10, 10), dpi=100)
sns.histplot(df['CarbonEmission'], kde=True, color='blue', bins=30)
plt.title('Distribution of Carbon Emissions')
plt.xlabel('Carbon Emission')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# <span style="color:blue">Right skeked distribution:</span> <br>
# Single peak, long tail to the right, very high emission values pulling the mean (2269) above the median (2080).
#
# <span style="color:blue">Concentration Cluster:</span>
#  <br>
# Between 1500-3000, suggesting most people have moderate emissions in this range.
#
# <span style="color:blue">Minimum Value:</span>
#  <br>306, indicating there are some very low emitters.
#
# <span style="color:blue">Maximum Value:</span>
#  <br>8377, showing there are also some extreme high emitters.
#
# <span style="color:blue">Outliers:</span>
#  <br>
#
# The shape is unimodal and fairly smooth, no major outliers.<br>
#
# *However, on the upper end, values above approximately 6000 could potentially be considered outliers. The bulk of the distribution lies between 1500-3000, so emissions higher than 6000 seem unusually high. Specifically, there is a cluster of points between 7000-8000 that protrudes quite far past the rest of the distribution.*

# %%
df.head()
# Out:
#     Body Type     Sex         Diet How Often Shower Heating Energy Source  \
# 0  overweight  female  pescatarian            daily                  coal
# 1       obese  female   vegetarian  less frequently           natural gas
# 2  overweight    male     omnivore  more frequently                  wood
# 3  overweight    male     omnivore      twice a day                  wood
# 4       obese  female   vegetarian            daily                  coal
#
#       Transport Vehicle Type Social Activity  Monthly Grocery Bill  \
# 0        public          NaN           often                   230
# 1  walk/bicycle          NaN           often                   114
# 2       private       petrol           never                   138
# 3  walk/bicycle          NaN       sometimes                   157
# 4       private       diesel           often                   266
#
#   Frequency of Traveling by Air  Vehicle Monthly Distance Km Waste Bag Size  \
# 0                    frequently                          210          large
# 1                        rarely                            9    extra large
# 2                         never                         2472          small
# 3                        rarely                           74         medium
# 4               very frequently                         8457          large
#
#    Waste Bag Weekly Count  How Long TV PC Daily Hour  \
# 0                       4                          7
# 1                       3                          9
# 2                       1                         14
# 3                       3                         20
# 4                       1                          3
#
#    How Many New Clothes Monthly  How Long Internet Daily Hour  \
# 0                            26                             1
# 1                            38                             5
# 2                            47                             6
# 3                             5                             7
# 4                             5                             6
#
#   Energy efficiency                               Recycling  \
# 0                No                               ['Metal']
# 1                No                               ['Metal']
# 2         Sometimes                               ['Metal']
# 3         Sometimes  ['Paper', 'Plastic', 'Glass', 'Metal']
# 4               Yes                               ['Paper']
#
#                          Cooking_With  CarbonEmission
# 0                   ['Stove', 'Oven']            2238
# 1              ['Stove', 'Microwave']            1892
# 2               ['Oven', 'Microwave']            2595
# 3  ['Microwave', 'Grill', 'Airfryer']            1074
# 4                            ['Oven']            4743

# %% [markdown]
# <span style="color:green">**Feature Engeeniring**</span>
#  <br>

# %%
from sklearn.preprocessing import StandardScaler
import pandas as pd

# One-hot encoding
df_encoded = pd.get_dummies(df)

# Initialize the scaler
scaler = StandardScaler()

# Fit and transform the data
df_scaled = scaler.fit_transform(df_encoded)

# %%
df_encoded.tail()
# Out:
#       Monthly Grocery Bill  Vehicle Monthly Distance Km  \
# 9995                   230                          268
# 9996                   234                         5316
# 9997                   298                           96
# 9998                   179                         8688
# 9999                   115                         9952
#
#       Waste Bag Weekly Count  How Long TV PC Daily Hour  \
# 9995                       5                         12
# 9996                       3                         14
# 9997                       5                         11
# 9998                       5                         19
# 9999                       4                         11
#
#       How Many New Clothes Monthly  How Long Internet Daily Hour  \
# 9995                            27                             9
# 9996                             8                            24
# 9997                             5                            24
# 9998                            14                             5
# 9999                             6                             0
#
#       CarbonEmission  Body Type_normal  Body Type_obese  Body Type_overweight  \
# 9995            2408                 0                1                     0
# 9996            3084                 1                0                     0
# 9997            2377                 0                0                     1
# 9998            4574                 0                0                     0
# 9999             826                 0                1                     0
#
#       ...  Cooking_With_['Oven']  Cooking_With_['Stove', 'Grill', 'Airfryer']  \
# 9995  ...                      0                                            0
# 9996  ...                      0                                            0
# 9997  ...                      0                                            0
# 9998  ...                      0                                            0
# 9999  ...                      0                                            0
#
#       Cooking_With_['Stove', 'Microwave', 'Grill', 'Airfryer']  \
# 9995                                                  0
# 9996                                                  0
# 9997                                                  0
# 9998                                                  1
# 9999                                                  0
#
#       Cooking_With_['Stove', 'Microwave']  \
# 9995                                    0
# 9996                                    1
# 9997                                    0
# 9998                                    0
# 9999                                    0
#
#       Cooking_With_['Stove', 'Oven', 'Grill', 'Airfryer']  \
# 9995                                                  0
# 9996                                                  0
# 9997                                                  0
# 9998                                                  0
# 9999                                                  0
#
#       Cooking_With_['Stove', 'Oven', 'Microwave', 'Grill', 'Airfryer']  \
# 9995                                                  0
# 9996                                                  0
# 9997                                                  0
# 9998                                                  0
# 9999                                                  0
#
#       Cooking_With_['Stove', 'Oven', 'Microwave']  \
# 9995                                            0
# 9996                                            0
# 9997                                            0
# 9998                                            0
# 9999                                            0
#
#       Cooking_With_['Stove', 'Oven']  Cooking_With_['Stove']  Cooking_With_[]
# 9995                               0                       0                0
# 9996                               0                       0                0
# 9997                               0                       0                0
# 9998                               0                       0                0
# 9999                               0                       0                0
#
# [5 rows x 79 columns]

# %%
# To a pandas DataFrame
df = pd.DataFrame(df_encoded)

# Save the DataFrame to a df_encoded.csv' 
df.to_csv('df_encoded.csv', index=False)

# %%
# Corr table afer encoding 
corr = df_encoded.corr()
corr
# Out:
#                                                     Monthly Grocery Bill  \
# Monthly Grocery Bill                                            1.000000
# Vehicle Monthly Distance Km                                     0.015801
# Waste Bag Weekly Count                                          0.002343
# How Long TV PC Daily Hour                                      -0.010318
# How Many New Clothes Monthly                                    0.006746
# ...                                                                  ...
# Cooking_With_['Stove', 'Oven', 'Microwave', 'Gr...              0.009810
# Cooking_With_['Stove', 'Oven', 'Microwave']                     0.009470
# Cooking_With_['Stove', 'Oven']                                  0.009079
# Cooking_With_['Stove']                                          0.004649
# Cooking_With_[]                                                -0.013602
#
#                                                     Vehicle Monthly Distance Km  \
# Monthly Grocery Bill                                                   0.015801
# Vehicle Monthly Distance Km                                            1.000000
# Waste Bag Weekly Count                                                -0.001730
# How Long TV PC Daily Hour                                             -0.003943
# How Many New Clothes Monthly                                           0.004934
# ...                                                                         ...
# Cooking_With_['Stove', 'Oven', 'Microwave', 'Gr...                    -0.010377
# Cooking_With_['Stove', 'Oven', 'Microwave']                           -0.004510
# Cooking_With_['Stove', 'Oven']                                         0.017809
# Cooking_With_['Stove']                                                 0.011046
# Cooking_With_[]                                                       -0.012479
#
#                                                     Waste Bag Weekly Count  \
# Monthly Grocery Bill                                              0.002343
# Vehicle Monthly Distance Km                                      -0.001730
# Waste Bag Weekly Count                                            1.000000
# How Long TV PC Daily Hour                                        -0.011640
# How Many New Clothes Monthly                                     -0.003254
# ...                                                                    ...
# Cooking_With_['Stove', 'Oven', 'Microwave', 'Gr...               -0.004253
# Cooking_With_['Stove', 'Oven', 'Microwave']                       0.003014
# Cooking_With_['Stove', 'Oven']                                   -0.007532
# Cooking_With_['Stove']                                           -0.009880
# Cooking_With_[]                                                   0.002990
#
#                                                     How Long TV PC Daily Hour  \
# Monthly Grocery Bill                                                -0.010318
# Vehicle Monthly Distance Km                                         -0.003943
# Waste Bag Weekly Count                                              -0.011640
# How Long TV PC Daily Hour                                            1.000000
# How Many New Clothes Monthly                                         0.009414
# ...                                                                       ...
# Cooking_With_['Stove', 'Oven', 'Microwave', 'Gr...                  -0.002574
# Cooking_With_['Stove', 'Oven', 'Microwave']                         -0.020675
# Cooking_With_['Stove', 'Oven']                                      -0.010315
# Cooking_With_['Stove']                                              -0.009516
# Cooking_With_[]                                                     -0.003307
#
#                                                     How Many New Clothes Monthly  \
# Monthly Grocery Bill                                                    0.006746
# Vehicle Monthly Distance Km                                             0.004934
# Waste Bag Weekly Count                                                 -0.003254
# How Long TV PC Daily Hour                                               0.009414
# How Many New Clothes Monthly                                            1.000000
# ...                                                                          ...
# Cooking_With_['Stove', 'Oven', 'Microwave', 'Gr...                      0.011354
# Cooking_With_['Stove', 'Oven', 'Microwave']                            -0.006351
# Cooking_With_['Stove', 'Oven']                                         -0.006232
# Cooking_With_['Stove']                                                  0.011074
# Cooking_With_[]                                                        -0.002622
#
#                                                     How Long Internet Daily Hour  \
# Monthly Grocery Bill                                                    0.012798
# Vehicle Monthly Distance Km                                            -0.003497
# Waste Bag Weekly Count                                                 -0.005335
# How Long TV PC Daily Hour                                               0.006804
# How Many New Clothes Monthly                                            0.006426
# ...                                                                          ...
# Cooking_With_['Stove', 'Oven', 'Microwave', 'Gr...                      0.002906
# Cooking_With_['Stove', 'Oven', 'Microwave']                             0.016973
# Cooking_With_['Stove', 'Oven']                                         -0.001522
# Cooking_With_['Stove']                                                 -0.012503
# Cooking_With_[]                                                         0.002937
#
#                                                     CarbonEmission  \
# Monthly Grocery Bill                                      0.081587
# Vehicle Monthly Distance Km                               0.594171
# Waste Bag Weekly Count                                    0.159193
# How Long TV PC Daily Hour                                 0.012985
# How Many New Clothes Monthly                              0.198887
# ...                                                            ...
# Cooking_With_['Stove', 'Oven', 'Microwave', 'Gr...        0.019397
# Cooking_With_['Stove', 'Oven', 'Microwave']              -0.004261
# Cooking_With_['Stove', 'Oven']                            0.007820
# Cooking_With_['Stove']                                    0.005759
# Cooking_With_[]                                          -0.024132
#
#                                                     Body Type_normal  \
# Monthly Grocery Bill                                        0.025083
# Vehicle Monthly Distance Km                                -0.008366
# Waste Bag Weekly Count                                      0.001882
# How Long TV PC Daily Hour                                   0.004069
# How Many New Clothes Monthly                               -0.010306
# ...                                                              ...
# Cooking_With_['Stove', 'Oven', 'Microwave', 'Gr...         -0.009994
# Cooking_With_['Stove', 'Oven', 'Microwave']                -0.001246
# Cooking_With_['Stove', 'Oven']                             -0.004349
# Cooking_With_['Stove']                                     -0.005460
# Cooking_With_[]                                             0.005723
#
#                                                     Body Type_obese  \
# Monthly Grocery Bill                                      -0.006436
# Vehicle Monthly Distance Km                                0.008982
# Waste Bag Weekly Count                                    -0.005976
# How Long TV PC Daily Hour                                 -0.002112
# How Many New Clothes Monthly                               0.006183
# ...                                                             ...
# Cooking_With_['Stove', 'Oven', 'Microwave', 'Gr...         0.016785
# Cooking_With_['Stove', 'Oven', 'Microwave']               -0.002856
# Cooking_With_['Stove', 'Oven']                             0.018012
# Cooking_With_['Stove']                                     0.011382
# Cooking_With_[]                                           -0.008489
#
#                                                     Body Type_overweight  ...  \
# Monthly Grocery Bill                                           -0.014018  ...
# Vehicle Monthly Distance Km                                     0.000315  ...
# Waste Bag Weekly Count                                          0.000793  ...
# How Long TV PC Daily Hour                                      -0.003132  ...
# How Many New Clothes Monthly                                   -0.007289  ...
# ...                                                                  ...  ...
# Cooking_With_['Stove', 'Oven', 'Microwave', 'Gr...             -0.011767  ...
# Cooking_With_['Stove', 'Oven', 'Microwave']                    -0.017340  ...
# Cooking_With_['Stove', 'Oven']                                 -0.005208  ...
# Cooking_With_['Stove']                                         -0.008213  ...
# Cooking_With_[]                                                -0.007742  ...
#
#                                                     Cooking_With_['Oven']  \
# Monthly Grocery Bill                                            -0.016601
# Vehicle Monthly Distance Km                                      0.004093
# Waste Bag Weekly Count                                          -0.013032
# How Long TV PC Daily Hour                                        0.015412
# How Many New Clothes Monthly                                    -0.008268
# ...                                                                   ...
# Cooking_With_['Stove', 'Oven', 'Microwave', 'Gr...              -0.066306
# Cooking_With_['Stove', 'Oven', 'Microwave']                     -0.065805
# Cooking_With_['Stove', 'Oven']                                  -0.068122
# Cooking_With_['Stove']                                          -0.064509
# Cooking_With_[]                                                 -0.064396
#
#                                                     Cooking_With_['Stove', 'Grill', 'Airfryer']  \
# Monthly Grocery Bill                                                                  -0.005168
# Vehicle Monthly Distance Km                                                           -0.002293
# Waste Bag Weekly Count                                                                -0.005685
# How Long TV PC Daily Hour                                                             -0.001590
# How Many New Clothes Monthly                                                           0.016393
# ...                                                                                         ...
# Cooking_With_['Stove', 'Oven', 'Microwave', 'Gr...                                    -0.067519
# Cooking_With_['Stove', 'Oven', 'Microwave']                                           -0.067008
# Cooking_With_['Stove', 'Oven']                                                        -0.069368
# Cooking_With_['Stove']                                                                -0.065689
# Cooking_With_[]                                                                       -0.065573
#
#                                                     Cooking_With_['Stove', 'Microwave', 'Grill', 'Airfryer']  \
# Monthly Grocery Bill                                                                         0.001769
# Vehicle Monthly Distance Km                                                                  0.002248
# Waste Bag Weekly Count                                                                       0.008540
# How Long TV PC Daily Hour                                                                    0.006341
# How Many New Clothes Monthly                                                                 0.001128
# ...                                                                                               ...
# Cooking_With_['Stove', 'Oven', 'Microwave', 'Gr...                                          -0.068885
# Cooking_With_['Stove', 'Oven', 'Microwave']                                                 -0.068364
# Cooking_With_['Stove', 'Oven']                                                              -0.070772
# Cooking_With_['Stove']                                                                      -0.067018
# Cooking_With_[]                                                                             -0.066900
#
#                                                     Cooking_With_['Stove', 'Microwave']  \
# Monthly Grocery Bill                                                          -0.004987
# Vehicle Monthly Distance Km                                                   -0.014886
# Waste Bag Weekly Count                                                         0.020264
# How Long TV PC Daily Hour                                                      0.000814
# How Many New Clothes Monthly                                                   0.000643
# ...                                                                                 ...
# Cooking_With_['Stove', 'Oven', 'Microwave', 'Gr...                            -0.067347
# Cooking_With_['Stove', 'Oven', 'Microwave']                                   -0.066837
# Cooking_With_['Stove', 'Oven']                                                -0.069191
# Cooking_With_['Stove']                                                        -0.065521
# Cooking_With_[]                                                               -0.065406
#
#                                                     Cooking_With_['Stove', 'Oven', 'Grill', 'Airfryer']  \
# Monthly Grocery Bill                                                                         0.010669
# Vehicle Monthly Distance Km                                                                 -0.017723
# Waste Bag Weekly Count                                                                       0.007288
# How Long TV PC Daily Hour                                                                   -0.003089
# How Many New Clothes Monthly                                                                 0.001582
# ...                                                                                               ...
# Cooking_With_['Stove', 'Oven', 'Microwave', 'Gr...                                          -0.065664
# Cooking_With_['Stove', 'Oven', 'Microwave']                                                 -0.065167
# Cooking_With_['Stove', 'Oven']                                                              -0.067463
# Cooking_With_['Stove']                                                                      -0.063885
# Cooking_With_[]                                                                             -0.063772
#
#                                                     Cooking_With_['Stove', 'Oven', 'Microwave', 'Grill', 'Airfryer']  \
# Monthly Grocery Bill                                                                         0.009810
# Vehicle Monthly Distance Km                                                                 -0.010377
# Waste Bag Weekly Count                                                                      -0.004253
# How Long TV PC Daily Hour                                                                   -0.002574
# How Many New Clothes Monthly                                                                 0.011354
# ...                                                                                               ...
# Cooking_With_['Stove', 'Oven', 'Microwave', 'Gr...                                           1.000000
# Cooking_With_['Stove', 'Oven', 'Microwave']                                                 -0.067519
# Cooking_With_['Stove', 'Oven']                                                              -0.069897
# Cooking_With_['Stove']                                                                      -0.066190
# Cooking_With_[]                                                                             -0.066073
#
#                                                     Cooking_With_['Stove', 'Oven', 'Microwave']  \
# Monthly Grocery Bill                                                                   0.009470
# Vehicle Monthly Distance Km                                                           -0.004510
# Waste Bag Weekly Count                                                                 0.003014
# How Long TV PC Daily Hour                                                             -0.020675
# How Many New Clothes Monthly                                                          -0.006351
# ...                                                                                         ...
# Cooking_With_['Stove', 'Oven', 'Microwave', 'Gr...                                    -0.067519
# Cooking_With_['Stove', 'Oven', 'Microwave']                                            1.000000
# Cooking_With_['Stove', 'Oven']                                                        -0.069368
# Cooking_With_['Stove']                                                                -0.065689
# Cooking_With_[]                                                                       -0.065573
#
#                                                     Cooking_With_['Stove', 'Oven']  \
# Monthly Grocery Bill                                                      0.009079
# Vehicle Monthly Distance Km                                               0.017809
# Waste Bag Weekly Count                                                   -0.007532
# How Long TV PC Daily Hour                                                -0.010315
# How Many New Clothes Monthly                                             -0.006232
# ...                                                                            ...
# Cooking_With_['Stove', 'Oven', 'Microwave', 'Gr...                       -0.069897
# Cooking_With_['Stove', 'Oven', 'Microwave']                              -0.069368
# Cooking_With_['Stove', 'Oven']                                            1.000000
# Cooking_With_['Stove']                                                   -0.068003
# Cooking_With_[]                                                          -0.067883
#
#                                                     Cooking_With_['Stove']  \
# Monthly Grocery Bill                                              0.004649
# Vehicle Monthly Distance Km                                       0.011046
# Waste Bag Weekly Count                                           -0.009880
# How Long TV PC Daily Hour                                        -0.009516
# How Many New Clothes Monthly                                      0.011074
# ...                                                                    ...
# Cooking_With_['Stove', 'Oven', 'Microwave', 'Gr...               -0.066190
# Cooking_With_['Stove', 'Oven', 'Microwave']                      -0.065689
# Cooking_With_['Stove', 'Oven']                                   -0.068003
# Cooking_With_['Stove']                                            1.000000
# Cooking_With_[]                                                  -0.064283
#
#                                                     Cooking_With_[]
# Monthly Grocery Bill                                      -0.013602
# Vehicle Monthly Distance Km                               -0.012479
# Waste Bag Weekly Count                                     0.002990
# How Long TV PC Daily Hour                                 -0.003307
# How Many New Clothes Monthly                              -0.002622
# ...                                                             ...
# Cooking_With_['Stove', 'Oven', 'Microwave', 'Gr...        -0.066073
# Cooking_With_['Stove', 'Oven', 'Microwave']               -0.065573
# Cooking_With_['Stove', 'Oven']                            -0.067883
# Cooking_With_['Stove']                                    -0.064283
# Cooking_With_[]                                            1.000000
#
# [79 rows x 79 columns]

# %%
# Correlation Matrix 
plt.figure(figsize=(40,40))
sns.heatmap(corr, annot=True, cmap='coolwarm', linewidths=0.8)
plt.title('Correlation')
plt.show()

# %% [markdown]
# <span style="color:green">**Pre-processing**</span>
#  <br>

# %%
# Split data / convert to numpy array
X = df_encoded.iloc[:, :-1].values 
y = df_encoded.iloc[:, -1].values

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
# Train and Test to .csv 
train = pd.DataFrame(X_train)
train['y'] = y_train

test = pd.DataFrame(X_test)  
test['y'] = y_test


train.to_csv('train.csv', index=False)
test.to_csv('test.csv', index=False)

# %%
from sklearn.preprocessing import StandardScaler
#Scaling
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df[numerical] = scaler.fit_transform(df[numerical])

# %%
# from sklearn.preprocessing import StandardScaler
# # Standardize the range(training data)
# sc = StandardScaler()
# X_train = sc.fit_transform(X_train)
# X_test = sc.transform(X_test)

# %%
df.tail()
# Out:
#       Monthly Grocery Bill  Vehicle Monthly Distance Km  \
# 9995              0.722892                     0.026803
# 9996              0.738956                     0.531653
# 9997              0.995984                     0.009601
# 9998              0.518072                     0.868887
# 9999              0.261044                     0.995300
#
#       Waste Bag Weekly Count  How Long TV PC Daily Hour  \
# 9995                0.666667                   0.500000
# 9996                0.333333                   0.583333
# 9997                0.666667                   0.458333
# 9998                0.666667                   0.791667
# 9999                0.500000                   0.458333
#
#       How Many New Clothes Monthly  How Long Internet Daily Hour  \
# 9995                          0.54                      0.375000
# 9996                          0.16                      1.000000
# 9997                          0.10                      1.000000
# 9998                          0.28                      0.208333
# 9999                          0.12                      0.000000
#
#       CarbonEmission  Body Type_normal  Body Type_obese  Body Type_overweight  \
# 9995        0.260439                 0                1                     0
# 9996        0.344195                 1                0                     0
# 9997        0.256598                 0                0                     1
# 9998        0.528807                 0                0                     0
# 9999        0.064428                 0                1                     0
#
#       ...  Cooking_With_['Oven']  Cooking_With_['Stove', 'Grill', 'Airfryer']  \
# 9995  ...                      0                                            0
# 9996  ...                      0                                            0
# 9997  ...                      0                                            0
# 9998  ...                      0                                            0
# 9999  ...                      0                                            0
#
#       Cooking_With_['Stove', 'Microwave', 'Grill', 'Airfryer']  \
# 9995                                                  0
# 9996                                                  0
# 9997                                                  0
# 9998                                                  1
# 9999                                                  0
#
#       Cooking_With_['Stove', 'Microwave']  \
# 9995                                    0
# 9996                                    1
# 9997                                    0
# 9998                                    0
# 9999                                    0
#
#       Cooking_With_['Stove', 'Oven', 'Grill', 'Airfryer']  \
# 9995                                                  0
# 9996                                                  0
# 9997                                                  0
# 9998                                                  0
# 9999                                                  0
#
#       Cooking_With_['Stove', 'Oven', 'Microwave', 'Grill', 'Airfryer']  \
# 9995                                                  0
# 9996                                                  0
# 9997                                                  0
# 9998                                                  0
# 9999                                                  0
#
#       Cooking_With_['Stove', 'Oven', 'Microwave']  \
# 9995                                            0
# 9996                                            0
# 9997                                            0
# 9998                                            0
# 9999                                            0
#
#       Cooking_With_['Stove', 'Oven']  Cooking_With_['Stove']  Cooking_With_[]
# 9995                               0                       0                0
# 9996                               0                       0                0
# 9997                               0                       0                0
# 9998                               0                       0                0
# 9999                               0                       0                0
#
# [5 rows x 79 columns]

# %%
df.to_csv("df_final.csv")
